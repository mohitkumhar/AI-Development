# %%
import pandas as pd
import requests

# %%
response = requests.get('https://newsapi.org/v2/everything?q=tesla&from=2024-06-22&sortBy=publishedAt&apiKey=ec1dc33f73174c69bfcb164a64e8c2ee')

# %%
response.json()
# Out:
# {'status': 'ok',
#  'totalResults': 9123,
#  'articles': [{'source': {'id': None, 'name': 'Deadline'},
#    'author': 'Caroline Frost',
#    'title': 'Trump Boasts Of Elon Musk’s Huge Donations; Says “We Have To Make Life Good” For Him And Other “Smart People”',
#    'description': 'Donald Trump was back at the lectern in Michigan last night, telling his supporters that he loves Elon Musk. This was the first joint event with his recent vice-presidential pick Sen. J.D. Vance (R-OH) and the first campaign rally since the attempted assassin…',
#    'url': 'http://deadline.com/2024/07/donald-trump-boasts-elon-musk-45m-a-month-donations-electric-cars-in-speech-1236016818/',
#    'urlToImage': 'https://deadline.com/wp-content/uploads/2024/07/GettyImages-2162829600.jpg?w=1024',
#    'publishedAt': '2024-07-21T08:09:00Z',
# ...

# %%
pd.DataFrame(response.json()['articles'])
# Out:
#                                              source  \
# 0                  {'id': None, 'name': 'Deadline'}
# 1            {'id': None, 'name': 'Anadolu Agency'}
# 2                    {'id': None, 'name': 'Futura'}
# 3   {'id': None, 'name': 'Hibridosyelectricos.com'}
# 4                    {'id': None, 'name': 'Forbes'}
# ..                                              ...
# 95                {'id': None, 'name': 'Dnyuz.com'}
# 96             {'id': None, 'name': 'Gizchina.com'}
# 97                 {'id': None, 'name': 'Futurism'}
# 98                 {'id': None, 'name': 'STERN.de'}
# 99                 {'id': None, 'name': 'Ixbt.com'}
#
#                                                author  \
# 0                                      Caroline Frost
# 1                                                None
# 2                           Arnaud Marchal, Rédacteur
# 3                                  Alejandro González
# 4   Brooke Crothers, Contributor, \n Brooke Crothe...
# ...

# %%
df = pd.DataFrame()

# %%
for i in range(913):
