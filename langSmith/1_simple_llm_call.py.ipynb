# %%
1492
# Out:
# 1492

# %% [markdown]
# # What is langSmith
# - langSmith is a unified observability and evaluation platform where teams can debug, test and monitor AI app performance

# %% [markdown]
# ### Observability:
# - It is the ability to understand a system's internal state by examining its external outputs, like logs, metrics and traces.
# - it allows you to diagnose issues, understand performance and improve reliability by analyzing data generated by the system.
# - Essentially, it's about being able to answer "why" something is happening within a system, even if you didn't anticipate the problem.

# %% [markdown]
# ### What Does LangSmith Trace ?
#
# 1. Input and Output
# 2. All the intermediate steps
# 3. Latency
# 4. Token Usage
# 5. Cost
# 6. Error
# 7. Tags
# 8. Metadata
# 9. Feedback

# %%
from langchain_openai import ChatOpenAI
from langchain_core.prompts import PromptTemplate
from langchain_core.output_parsers import StrOutputParser

# %%
from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# True

# %%
prompt = PromptTemplate(
    template="""
    Generate a 5 pointer summary from a following test \n {text}
    """,
    input_variables= ['text'],
)

# %%
OPEN_AI_KEY = "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"

# %%
model = ChatOpenAI(
    api_key="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",
    verbose=True,
    base_url="https://openrouter.ai/api/v1"
)

# %%
parser = StrOutputParser()

# %%
answer = prompt | model | parser

# %%
result = answer.invoke({"text": "Capital of India"})

# %%
result
# Out:
# 'Min: New Delhi\nQ1:  Mumbai\nMedian: New Delhi\nQ3: Kolkata\nMax: Bengaluru'
