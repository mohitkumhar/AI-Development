# %%
import os
from dotenv import load_dotenv
from langchain_community.document_loaders import PyPDFLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_openai import OpenAIEmbeddings, ChatOpenAI
from langchain_community.vectorstores import FAISS
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.runnables import RunnableParallel, RunnablePassthrough, RunnableLambda
from langchain_core.output_parsers import StrOutputParser

# %%
os.environ["LANGCHAIN_PROJECT"] = "RAG Chatbot" # to change the project name in langSmith

# %%
load_dotenv()  # expects OPENAI_API_KEY in .env
# Out:
# True

# %%
PDF_PATH = "resume.pdf"

# %%
# 1) Load PDF
loader = PyPDFLoader(PDF_PATH)
docs = loader.load()  # one Document per page

# %%
docs
# Out:
# [Document(metadata={'producer': 'www.ilovepdf.com', 'creator': 'Microsoft® Word 2016', 'creationdate': '2026-01-10T07:11:22+00:00', 'author': 'Umesh Kumhar', 'moddate': '2026-01-10T07:11:22+00:00', 'source': 'resume.pdf', 'total_pages': 2, 'page': 0, 'page_label': '1'}, page_content='MOHIT KUMHAR Backend Engineer|Data Science \n \n Jaipur | +91-7976-127-452 |  mohitmolela@gmail.com|   @mohitkumhar*| @mohitkumhar* \n \nSUMMARY \n \nBackend engineer and data science enthusiast with skills in Python, analytics, and machine learning, seeking \nopportunities to build impactful and scalable data-driven solutions that make a real impact. \n \nTECHNICAL SKILLS \nLanguages & Scripts: Python, C/C++ \nData Manipulation: Pandas, NumPy, Data Wrangling, Data Cleaning, Feature Engineering \nData Visualization: Matplotlib, Seaborn, Plotly \nMachine Learning: Scikit-learn, Model Deployment, Model Evaluation \nNatural Language Processing (NLP): Text Preprocessing, Sentiment Analysis, Named Entity Recognition (NER), \nWord Embeddings (Word2Vec), SpaCy \nModel Deployment: Flask API (for serving ML models), Docker, Heroku, Vercel, Streamlit, Netlify \nData Stores: MySQL, PostgreSQL, MongoDB \nVersion Control: Git, GitHub, GitLab \nOperating Systems: Windows, Linux (Ubuntu, Kali Linux), macOS \nTools & Libraries: Selenium, BeautifulSoup, Jupyter Notebooks, VS Code, Colab \nEDUCATION \nYear Degree / Certificate Institute Name Percentage \n2023 – 2027 B.Tech (3rd Year) Rajasthan Technical University Pursuing \n2022 – 2023 RBSE Board (Class XII) Shree Jee School 77.6 \n2020 – 2021 RBSE Board (Class X) Shree Jee School 85.0 \n \nPROFESSIONAL EXPERIENCE \nInternship in AI-Engineer August 2025 – October 2025 \nNudgeBee |Pune, Maharashtra \nKey Duties: \n● Fine-tune the LLM side of NudgeBee platform agents for tracing, logging, metrics, and recommendations to raise \naccuracy and reduce failure cases. \n● Design and run benchmark suites across Traces, AWS, Logs, GCP, Datadog agents to find failing scenarios. \n● Perform failure analysis and apply targeted fixes – Feature-signal improvements, Model-setting tweaks and Prompt- \nengineering to make agents handle edge cases better \n● Build observability and reporting to track agent performance and share results with the team. \n● Worked with backend and devops team on deployments and benchmarking tasks and wrote documentation for \nbenchmark workflows \n \n \nInternship in Recommendation Engine Development – Machine Learning July 2024 – August 2024 \nThe Terracotta Store | Udaipur, Rajasthan \nKey Duties: \n● Analyzed customer needs and business goals to design scalable, efficient machine-learning algorithm for \nrecommendation systems. \n● Built data-preprocessing pipelines in Pandas and NumPy to clean, transform and prepare datasets to feed model \n● Created clear dashboards and visualizations with Matplotlib, Seaborn and Plotly to share model results and insights \nwith stakeholders. \n● Worked closely with the ML and data teams to integrate model into the product, tune performance, and turn data \nfindings into actionable improvements.'),
#  Document(metadata={'producer': 'www.ilovepdf.com', 'creator': 'Microsoft® Word 2016', 'creationdate': '2026-01-10T07:11:22+00:00', 'author': 'Umesh Kumhar', 'moddate': '2026-01-10T07:11:22+00:00', 'source': 'resume.pdf', 'total_pages': 2, 'page': 1, 'page_label': '2'}, page_content='Projects: \n➔ Intelligent CCTV Surveillance Web Application \n● Built an intelligent CCTV system for real-time monitoring and automatic detection of people, accidents, etc. \n● Created a Streamlit web interface with WebRTC for live camera viewing and also upload-based analysis. \n● Used YOLO, DeepFace and custom TensorFlow models with OpenCV to detect objects, helmets and faces \naccurately and added audio-based analysis with Librosa like scream and gunshot detection. \n● Implemented alert system like wanted-person and wanted-vehicle, role-based access for admins and customers \n● Logged every event in MongoDB. \n ADDITIONAL ACTIVITIES & RECOGNITION  \n \n● Awarded swags at the Google Arcade event in recognition of active participation and strong performance \n● Solved 750+ problems on LeetCode \n● Managed the Nudgebee booth, representing the company and engaging with attendees \n● Participation Codefiesta 3.0 and Smart India Hackathon \n● Participation in Google Developers Group Seminar Jaipur and The AI Career & Community Day Pune \n● District Chess Winner Award – 2022 \n● State Chess Tournament Participant – 2022')]

# %%
# 2) Chunk
splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=150)
splits = splitter.split_documents(docs)

# %%
splits
# Out:
# [Document(metadata={'producer': 'www.ilovepdf.com', 'creator': 'Microsoft® Word 2016', 'creationdate': '2026-01-10T07:11:22+00:00', 'author': 'Umesh Kumhar', 'moddate': '2026-01-10T07:11:22+00:00', 'source': 'resume.pdf', 'total_pages': 2, 'page': 0, 'page_label': '1'}, page_content='MOHIT KUMHAR Backend Engineer|Data Science \n \n Jaipur | +91-7976-127-452 |  mohitmolela@gmail.com|   @mohitkumhar*| @mohitkumhar* \n \nSUMMARY \n \nBackend engineer and data science enthusiast with skills in Python, analytics, and machine learning, seeking \nopportunities to build impactful and scalable data-driven solutions that make a real impact. \n \nTECHNICAL SKILLS \nLanguages & Scripts: Python, C/C++ \nData Manipulation: Pandas, NumPy, Data Wrangling, Data Cleaning, Feature Engineering \nData Visualization: Matplotlib, Seaborn, Plotly \nMachine Learning: Scikit-learn, Model Deployment, Model Evaluation \nNatural Language Processing (NLP): Text Preprocessing, Sentiment Analysis, Named Entity Recognition (NER), \nWord Embeddings (Word2Vec), SpaCy \nModel Deployment: Flask API (for serving ML models), Docker, Heroku, Vercel, Streamlit, Netlify \nData Stores: MySQL, PostgreSQL, MongoDB \nVersion Control: Git, GitHub, GitLab \nOperating Systems: Windows, Linux (Ubuntu, Kali Linux), macOS'),
#  Document(metadata={'producer': 'www.ilovepdf.com', 'creator': 'Microsoft® Word 2016', 'creationdate': '2026-01-10T07:11:22+00:00', 'author': 'Umesh Kumhar', 'moddate': '2026-01-10T07:11:22+00:00', 'source': 'resume.pdf', 'total_pages': 2, 'page': 0, 'page_label': '1'}, page_content='Data Stores: MySQL, PostgreSQL, MongoDB \nVersion Control: Git, GitHub, GitLab \nOperating Systems: Windows, Linux (Ubuntu, Kali Linux), macOS \nTools & Libraries: Selenium, BeautifulSoup, Jupyter Notebooks, VS Code, Colab \nEDUCATION \nYear Degree / Certificate Institute Name Percentage \n2023 – 2027 B.Tech (3rd Year) Rajasthan Technical University Pursuing \n2022 – 2023 RBSE Board (Class XII) Shree Jee School 77.6 \n2020 – 2021 RBSE Board (Class X) Shree Jee School 85.0 \n \nPROFESSIONAL EXPERIENCE \nInternship in AI-Engineer August 2025 – October 2025 \nNudgeBee |Pune, Maharashtra \nKey Duties: \n● Fine-tune the LLM side of NudgeBee platform agents for tracing, logging, metrics, and recommendations to raise \naccuracy and reduce failure cases. \n● Design and run benchmark suites across Traces, AWS, Logs, GCP, Datadog agents to find failing scenarios. \n● Perform failure analysis and apply targeted fixes – Feature-signal improvements, Model-setting tweaks and Prompt-'),
#  Document(metadata={'producer': 'www.ilovepdf.com', 'creator': 'Microsoft® Word 2016', 'creationdate': '2026-01-10T07:11:22+00:00', 'author': 'Umesh Kumhar', 'moddate': '2026-01-10T07:11:22+00:00', 'source': 'resume.pdf', 'total_pages': 2, 'page': 0, 'page_label': '1'}, page_content='● Perform failure analysis and apply targeted fixes – Feature-signal improvements, Model-setting tweaks and Prompt- \nengineering to make agents handle edge cases better \n● Build observability and reporting to track agent performance and share results with the team. \n● Worked with backend and devops team on deployments and benchmarking tasks and wrote documentation for \nbenchmark workflows \n \n \nInternship in Recommendation Engine Development – Machine Learning July 2024 – August 2024 \nThe Terracotta Store | Udaipur, Rajasthan \nKey Duties: \n● Analyzed customer needs and business goals to design scalable, efficient machine-learning algorithm for \nrecommendation systems. \n● Built data-preprocessing pipelines in Pandas and NumPy to clean, transform and prepare datasets to feed model \n● Created clear dashboards and visualizations with Matplotlib, Seaborn and Plotly to share model results and insights \nwith stakeholders.'),
#  Document(metadata={'producer': 'www.ilovepdf.com', 'creator': 'Microsoft® Word 2016', 'creationdate': '2026-01-10T07:11:22+00:00', 'author': 'Umesh Kumhar', 'moddate': '2026-01-10T07:11:22+00:00', 'source': 'resume.pdf', 'total_pages': 2, 'page': 0, 'page_label': '1'}, page_content='● Created clear dashboards and visualizations with Matplotlib, Seaborn and Plotly to share model results and insights \nwith stakeholders. \n● Worked closely with the ML and data teams to integrate model into the product, tune performance, and turn data \nfindings into actionable improvements.'),
#  Document(metadata={'producer': 'www.ilovepdf.com', 'creator': 'Microsoft® Word 2016', 'creationdate': '2026-01-10T07:11:22+00:00', 'author': 'Umesh Kumhar', 'moddate': '2026-01-10T07:11:22+00:00', 'source': 'resume.pdf', 'total_pages': 2, 'page': 1, 'page_label': '2'}, page_content='Projects: \n➔ Intelligent CCTV Surveillance Web Application \n● Built an intelligent CCTV system for real-time monitoring and automatic detection of people, accidents, etc. \n● Created a Streamlit web interface with WebRTC for live camera viewing and also upload-based analysis. \n● Used YOLO, DeepFace and custom TensorFlow models with OpenCV to detect objects, helmets and faces \naccurately and added audio-based analysis with Librosa like scream and gunshot detection. \n● Implemented alert system like wanted-person and wanted-vehicle, role-based access for admins and customers \n● Logged every event in MongoDB. \n ADDITIONAL ACTIVITIES & RECOGNITION  \n \n● Awarded swags at the Google Arcade event in recognition of active participation and strong performance \n● Solved 750+ problems on LeetCode \n● Managed the Nudgebee booth, representing the company and engaging with attendees \n● Participation Codefiesta 3.0 and Smart India Hackathon'),
#  Document(metadata={'producer': 'www.ilovepdf.com', 'creator': 'Microsoft® Word 2016', 'creationdate': '2026-01-10T07:11:22+00:00', 'author': 'Umesh Kumhar', 'moddate': '2026-01-10T07:11:22+00:00', 'source': 'resume.pdf', 'total_pages': 2, 'page': 1, 'page_label': '2'}, page_content='● Managed the Nudgebee booth, representing the company and engaging with attendees \n● Participation Codefiesta 3.0 and Smart India Hackathon \n● Participation in Google Developers Group Seminar Jaipur and The AI Career & Community Day Pune \n● District Chess Winner Award – 2022 \n● State Chess Tournament Participant – 2022')]

# %%
# 3) Embed + index
emb = OpenAIEmbeddings(
    model="openai/text-embedding-3-small",
    base_url="https://openrouter.ai/api/v1",
)

# %%
vs = FAISS.from_documents(splits, emb)

# %%
retriever = vs.as_retriever(search_type="similarity", search_kwargs={"k": 4})

# %%
retriever
# Out:
# VectorStoreRetriever(tags=['FAISS', 'OpenAIEmbeddings'], vectorstore=<langchain_community.vectorstores.faiss.FAISS object at 0x000002074AAB8B10>, search_kwargs={'k': 4})

# %%
# 4) Prompt
prompt = ChatPromptTemplate.from_messages([
    ("system", "Answer ONLY from the provided context. If not found, say you don't know."),
    ("human", "Question: {question}\n\nContext:\n{context}")
])

# %%
# 5) Chain
llm = ChatOpenAI(
    base_url="https://openrouter.ai/api/v1",
    model="gpt-4o-mini", 
    temperature=0
)

# %%
def format_docs(docs):
    return "\n\n".join(d.page_content for d in docs)

# %%
parallel = RunnableParallel({
    "context": retriever | RunnableLambda(format_docs),
    "question": RunnablePassthrough()
})

# %%
chain = parallel | prompt | llm | StrOutputParser()

# %%
# 6) Ask questions
print("PDF RAG ready. Ask a question (or Ctrl+C to exit).")
q = input("\nQ: ")
# Out:
# PDF RAG ready. Ask a question (or Ctrl+C to exit).
# Q:  "what are my ml skills"

# %%
ans = chain.invoke(q.strip())
print("\nA:", ans)
# Out:
# A: Your machine learning skills include:
#
# - Proficiency in Python and relevant libraries such as Scikit-learn for machine learning.
# - Experience in model deployment using Flask API, Docker, Heroku, Vercel, Streamlit, and Netlify.
# - Knowledge of natural language processing (NLP) techniques including text preprocessing, sentiment analysis, named entity recognition (NER), and word embeddings (Word2Vec).
# - Ability to create data preprocessing pipelines using Pandas and NumPy for cleaning and transforming datasets.
# - Experience in building dashboards and visualizations with Matplotlib, Seaborn, and Plotly to communicate model results and insights.
# - Skills in model evaluation and performance tuning, as well as failure analysis and applying targeted fixes to improve model performance.

# %%
"what are my ml skills"
# Out:
# 'what are my ml skills'
