# %%
# To export Figure object to png, jpg or WebP format,

import plotly.io as pio
pio.write_image(fig, 'sinewave.png') # we can also export it in .jpeg/ .webp/ .svg/ .pdf
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 4
#       1 # To export Figure object to png, jpg or WebP format,
#       3 import plotly.io as pio
# ----> 4 pio.write_image(fig, 'sinewave.png') # we can also export it in .jpeg/ .webp/ .svg/ .pdf
#
# NameError: name 'fig' is not defined
