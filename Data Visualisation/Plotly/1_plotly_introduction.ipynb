# %% [markdown]
# # Introduction to Plotly

# %% [raw]
# Plotly Python package has three main modules which are given below −

# %% [raw]
# plotly.plotly
# plotly.graph_objs
# plotly.tools

# %% [raw]
# The plotly.plotly module acts as a bridge between your computer and Plotly's servers, allowing you to create and interact with graphs by sending requests and receiving responses.

# %% [raw]
# The plotly.graph_objs module is the most important module that contains all of the class definitions for the objects that make up the plots you see.
