# %%
layout = go.Layout(
    title = "Sine and cos",
    # The title of the graph
    
    xaxis = dict(
        title = 'angle',
        # Label for the x-axis
        
        showgrid = True,
        # Display grid lines on the x-axis
        
        zeroline = True,
        # Display the zero line on the x-axis
        
        showline = True,
        # Display the axis line for the x-axis
        
        showticklabels = True,
        # Show labels on the ticks of the x-axis
        
        gridwidth = 1
        # Width of the grid lines on the x-axis
    ),
    
    yaxis = dict(
        showgrid = True,
        # Display grid lines on the y-axis
        
        zeroline = True,
        # Display the zero line on the y-axis
        
        showline = True,
        # Display the axis line for the y-axis
        
        gridcolor = '#bdbdbd',
        # Color of the grid lines on the y-axis
        
        gridwidth = 2,
        # Width of the grid lines on the y-axis
        
        zerolinecolor = '#969696',
        # Color of the zero line on the y-axis
        
        zerolinewidth = 2,
        # Width of the zero line on the y-axis
        
        linecolor = '#636363',
        # Color of the axis line for the y-axis
        
        linewidth = 2,
        # Width of the axis line for the y-axis
        
        title = 'VALUE',
        # Label for the y-axis
        
        titlefont = dict(
            family = 'Arial, sans-serif',
            # Font family for the y-axis title
            
            size = 18,
            # Font size for the y-axis title
            
            color = 'lightgrey'
            # Font color for the y-axis title
        ),
        
        showticklabels = True,
        # Show labels on the ticks of the y-axis
        
        tickangle = 45,
        # Angle of the tick labels on the y-axis
        
        tickfont = dict(
            family = 'Old Standard TT, serif',
            # Font family for the tick labels on the y-axis
            
            size = 14,
            # Font size for the tick labels on the y-axis
            
            color = 'black'
            # Font color for the tick labels on the y-axis
        ),
        
        tickmode = 'linear',
        # Mode for the ticks on the y-axis (linear)
        
        tick0 = 0.0,
        # Starting tick value for the y-axis
        
        dtick = 0.25
        # Step size between ticks on the y-axis
    )
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 layout = go.Layout(
#       2     title = "Sine and cos",
#       3     # The title of the graph
#       4
#       5     xaxis = dict(
#       6         title = 'angle',
#       7         # Label for the x-axis
#       8
#       9         showgrid = True,
#      10         # Display grid lines on the x-axis
#      11
#      12         zeroline = True,
#      13         # Display the zero line on the x-axis
#      14
#      15         showline = True,
#      16         # Display the axis line for the x-axis
#      17
#      18         showticklabels = True,
#      19         # Show labels on the ticks of the x-axis
#      20
#      21         gridwidth = 1
#      22         # Width of the grid lines on the x-axis
#      23     ),
#      24
#      25     yaxis = dict(
#      26         showgrid = True,
# ...
