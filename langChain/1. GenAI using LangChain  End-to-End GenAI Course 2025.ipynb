# %% [markdown]
# # What is GenAI

# %% [markdown]
# Generative is a type of Artifical Intelligence that creates new content - such as text, images, music or code - by learning patterns feom existing data, mimicking human creativity

# %% [markdown]
# ![image.png](attachment:38b2ee8a-c6c7-4604-b25f-c472baf452a9.png)

# %% [markdown]
# # GenAI Impacts Area
# - Customer Support
# - Content Creation
# - Education
# - Software Development

# %% [markdown]
# # Is GenAI Successful
# - It Solves the real world Problems
# - It is useful on a Daily Bases
# - It is Impacting a Real World Economics
# - It is Creating New Jobs
# - It is Accessible

# %% [markdown]
# # How the AI System Works
# ![image.png](attachment:a23a4224-b4e6-40ec-a22e-66148eff3f59.png)

# %% [markdown]
# #### How they are Different
# ![image.png](attachment:e6ac281c-56d9-491e-b904-549c1759d71a.png)

# %% [markdown]
# # Builder's Perspective
# ![image.png](attachment:47ed2a6a-baf8-4dfe-b1c3-5856dda3e5be.png)

# %% [markdown]
# # The user's Perspective
# ![image.png](attachment:4a622060-f4dd-46b3-9a4c-5dec107d6cb4.png)

# %% [markdown]
# # Do we Learn Both
# ![image.png](attachment:3bc3dd1d-7683-4b89-ba20-aefe3f4c26c3.png)
