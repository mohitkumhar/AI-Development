# %% [markdown]
# # LangChain RoadMap

# %% [markdown]
# 1. Fundamentals
#     - What is LangChain
#     - LangChain Components
#     - Models
#     - Prompts
#     - Parsing Ouput
#     - Runnables & LCEL
#     - Chains
#     - Memory
#
# 2. RAG
#     - Document Loaders
#     - Text Splitters
#     - Embeddings
#     - Vector Stores
#     - Retrievers
#     - Building a RAG application
#
# 4. Agents
#     - Tools & Toolkits
#     - Tool Calling
#     - Building and AI Agent
