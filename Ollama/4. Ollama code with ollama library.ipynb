# %% [markdown]
# # OLLAMA LIBRARY

# %%
! pip install ollama
# Out:
# Collecting ollama
#   Using cached ollama-0.6.1-py3-none-any.whl.metadata (4.3 kB)
# Collecting httpx>=0.27 (from ollama)
#   Using cached httpx-0.28.1-py3-none-any.whl.metadata (7.1 kB)
# Collecting pydantic>=2.9 (from ollama)
#   Using cached pydantic-2.12.5-py3-none-any.whl.metadata (90 kB)
# Collecting anyio (from httpx>=0.27->ollama)
#   Downloading anyio-4.12.1-py3-none-any.whl.metadata (4.3 kB)
# Collecting certifi (from httpx>=0.27->ollama)
#   Using cached certifi-2026.1.4-py3-none-any.whl.metadata (2.5 kB)
# Collecting httpcore==1.* (from httpx>=0.27->ollama)
#   Using cached httpcore-1.0.9-py3-none-any.whl.metadata (21 kB)
# Collecting idna (from httpx>=0.27->ollama)
#   Using cached idna-3.11-py3-none-any.whl.metadata (8.4 kB)
# Collecting h11>=0.16 (from httpcore==1.*->httpx>=0.27->ollama)
#   Using cached h11-0.16.0-py3-none-any.whl.metadata (8.3 kB)
# Collecting annotated-types>=0.6.0 (from pydantic>=2.9->ollama)
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.41.5 (from pydantic>=2.9->ollama)
#   Using cached pydantic_core-2.41.5-cp311-cp311-win_amd64.whl.metadata (7.4 kB)
# Requirement already satisfied: typing-extensions>=4.14.1 in c:\users\write\appdata\roaming\python\python311\site-packages (from pydantic>=2.9->ollama) (4.15.0)
# Collecting typing-inspection>=0.4.2 (from pydantic>=2.9->ollama)
#   Using cached typing_inspection-0.4.2-py3-none-any.whl.metadata (2.6 kB)
# Using cached ollama-0.6.1-py3-none-any.whl (14 kB)
# Using cached httpx-0.28.1-py3-none-any.whl (73 kB)
# Using cached httpcore-1.0.9-py3-none-any.whl (78 kB)
# Using cached pydantic-2.12.5-py3-none-any.whl (463 kB)
# Using cached pydantic_core-2.41.5-cp311-cp311-win_amd64.whl (2.0 MB)
# Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Using cached typing_inspection-0.4.2-py3-none-any.whl (14 kB)
# Downloading anyio-4.12.1-py3-none-any.whl (113 kB)
#    ---------------------------------------- 0.0/113.6 kB ? eta -:--:--
#    ---------------------------------------- 0.0/113.6 kB ? eta -:--:--
#    ---------------------------------------- 0.0/113.6 kB ? eta -:--:--
#    ---------------------------------------- 0.0/113.6 kB ? eta -:--:--
#    ---------------------------------------- 0.0/113.6 kB ? eta -:--:--
#    --- ------------------------------------ 10.2/113.6 kB ? eta -:--:--
#    --- ------------------------------------ 10.2/113.6 kB ? eta -:--:--
#    --- ------------------------------------ 10.2/113.6 kB ? eta -:--:--
#    --- ------------------------------------ 10.2/113.6 kB ? eta -:--:--
#    --- ------------------------------------ 10.2/113.6 kB ? eta -:--:--
#    --- ------------------------------------ 10.2/113.6 kB ? eta -:--:--
#    --- ------------------------------------ 10.2/113.6 kB ? eta -:--:--
#    --- ------------------------------------ 10.2/113.6 kB ? eta -:--:--
#    --- ------------------------------------ 10.2/113.6 kB ? eta -:--:--
#    --------------------- ----------------- 61.4/113.6 kB 121.6 kB/s eta 0:00:01
#    --------------------- ----------------- 61.4/113.6 kB 121.6 kB/s eta 0:00:01
#    ---------------------------- ---------- 81.9/113.6 kB 148.1 kB/s eta 0:00:01
#    ---------------------------- ---------- 81.9/113.6 kB 148.1 kB/s eta 0:00:01
#    -------------------------------------  112.6/113.6 kB 172.7 kB/s eta 0:00:01
#    -------------------------------------- 113.6/113.6 kB 165.4 kB/s eta 0:00:00
# Using cached idna-3.11-py3-none-any.whl (71 kB)
# Using cached certifi-2026.1.4-py3-none-any.whl (152 kB)
# Using cached h11-0.16.0-py3-none-any.whl (37 kB)
# Installing collected packages: typing-inspection, pydantic-core, idna, h11, certifi, annotated-types, pydantic, httpcore, anyio, httpx, ollama
# Successfully installed annotated-types-0.7.0 anyio-4.12.1 certifi-2026.1.4 h11-0.16.0 httpcore-1.0.9 httpx-0.28.1 idna-3.11 ollama-0.6.1 pydantic-2.12.5 pydantic-core-2.41.5 typing-inspection-0.4.2
# [notice] A new release of pip is available: 24.0 -> 26.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import ollama

# %% [markdown]
# ## Generate Function

# %%
# GENERATION
response = ollama.generate(model="llama3.2:1b",prompt="why does moon glow ?")

# %%
response
# Out:
# GenerateResponse(model='llama3.2:1b', created_at='2026-02-02T18:19:05.9053841Z', done=True, done_reason='stop', total_duration=7256035300, load_duration=353150500, prompt_eval_count=30, prompt_eval_duration=351084700, eval_count=368, eval_duration=5884597400, response='The Moon glows due to a process called lunar illumination, which occurs when sunlight reflects off the Moon\'s surface. Here\'s why:\n\n1. **Reflection of sunlight**: When sunlight hits the Earth\'s atmosphere, it encounters tiny molecules of gases like nitrogen and oxygen. These molecules scatter the shorter, blue wavelengths of light more than the longer, red wavelengths, a phenomenon known as Rayleigh scattering. This is why the sky appears blue during the day.\n2. **Reflected sunlight**: The scattered light is then reflected off the Moon\'s surface, which is composed mainly of gray rock and dust. The reflected light contains all the colors of the visible spectrum, including the blue and violet hues that are usually invisible to the human eye.\n3. **Moon\'s reflectivity**: The Moon has a high albedo (reflectivity), meaning it reflects about 12% of the sunlight that hits its surface. This is why we can see the Moon in the night sky, even when it\'s not directly illuminated by the Sun.\n\nThe combination of these factors makes the Moon glow with a soft, silvery light, which is often described as "glowing" or "illuminating." The intensity and color of the glow depend on several factors, including:\n\n* **Phase of the Moon**: The Moon glows more brightly when it\'s full and new, as more sunlight can reflect off its surface.\n* **Atmospheric conditions**: Pollution, dust, and water vapor in the atmosphere can scatter light and reduce the Moon\'s brightness.\n* **Time of day**: The Moon\'s glow is strongest near the horizon during the day and decreases as it moves away from the observer.\n\nOverall, the combination of sunlight reflection off the Moon\'s surface and its own reflectivity makes the Moon a stunning celestial object that we can observe in the night sky.', thinking=None, context=[128006, 9125, 128007, 271, 38766, 1303, 33025, 2696, 25, 6790, 220, 2366, 18, 271, 128009, 128006, 882, 128007, 271, 35734, 1587, 18266, 37066, 949, 128009, 128006, 78191, 128007, 271, 791, 17781, 2840, 4336, 4245, 311, 264, 1920, 2663, 57811, 77052, 11, 902, 13980, 994, 40120, 27053, 1022, 279, 17781, 596, 7479, 13, 5810, 596, 3249, 1473, 16, 13, 3146, 45338, 315, 40120, 96618, 3277, 40120, 13280, 279, 9420, 596, 16975, 11, 433, 35006, 13987, 35715, 315, 45612, 1093, 47503, 323, 24463, 13, 4314, 35715, 45577, 279, 24210, 11, 6437, 93959, 315, 3177, 810, 1109, 279, 5129, 11, 2579, 93959, 11, 264, 25885, 3967, 439, 13558, 64069, 72916, 13, 1115, 374, 3249, 279, 13180, 8111, 6437, 2391, 279, 1938, 627, 17, 13, 3146, 4032, 2258, 40120, 96618, 578, 38067, 3177, 374, 1243, 27000, 1022, 279, 17781, 596, 7479, 11, 902, 374, 24306, 14918, 315, 18004, 7091, 323, 16174, 13, 578, 27000, 3177, 5727, 682, 279, 8146, 315, 279, 9621, 20326, 11, 2737, 279, 6437, 323, 80836, 82757, 430, 527, 6118, 30547, 311, 279, 3823, 8071, 627, 18, 13, 3146, 77119, 596, 8881, 1968, 96618, 578, 17781, 706, 264, 1579, 453, 90087, 320, 36013, 1968, 705, 7438, 433, 27053, 922, 220, 717, 4, 315, 279, 40120, 430, 13280, 1202, 7479, 13, 1115, 374, 3249, 584, 649, 1518, 279, 17781, 304, 279, 3814, 13180, 11, 1524, 994, 433, 596, 539, 6089, 75648, 555, 279, 8219, 382, 791, 10824, 315, 1521, 9547, 3727, 279, 17781, 37066, 449, 264, 8579, 11, 5554, 1225, 3177, 11, 902, 374, 3629, 7633, 439, 330, 6200, 24060, 1, 477, 330, 484, 10318, 1113, 1210, 578, 21261, 323, 1933, 315, 279, 37066, 6904, 389, 3892, 9547, 11, 2737, 1473, 9, 3146, 31833, 315, 279, 17781, 96618, 578, 17781, 2840, 4336, 810, 76389, 994, 433, 596, 2539, 323, 502, 11, 439, 810, 40120, 649, 8881, 1022, 1202, 7479, 627, 9, 3146, 1688, 8801, 33349, 4787, 96618, 96201, 11, 16174, 11, 323, 3090, 38752, 304, 279, 16975, 649, 45577, 3177, 323, 8108, 279, 17781, 59 ...

# %%
print(response.response)
# Out:
# The Moon glows due to a process called lunar illumination, which occurs when sunlight reflects off the Moon's surface. Here's why:
#
# 1. **Reflection of sunlight**: When sunlight hits the Earth's atmosphere, it encounters tiny molecules of gases like nitrogen and oxygen. These molecules scatter the shorter, blue wavelengths of light more than the longer, red wavelengths, a phenomenon known as Rayleigh scattering. This is why the sky appears blue during the day.
# 2. **Reflected sunlight**: The scattered light is then reflected off the Moon's surface, which is composed mainly of gray rock and dust. The reflected light contains all the colors of the visible spectrum, including the blue and violet hues that are usually invisible to the human eye.
# 3. **Moon's reflectivity**: The Moon has a high albedo (reflectivity), meaning it reflects about 12% of the sunlight that hits its surface. This is why we can see the Moon in the night sky, even when it's not directly illuminated by the Sun.
#
# The combination of these factors makes the Moon glow with a soft, silvery light, which is often described as "glowing" or "illuminating." The intensity and color of the glow depend on several factors, including:
#
# * **Phase of the Moon**: The Moon glows more brightly when it's full and new, as more sunlight can reflect off its surface.
# * **Atmospheric conditions**: Pollution, dust, and water vapor in the atmosphere can scatter light and reduce the Moon's brightness.
# * **Time of day**: The Moon's glow is strongest near the horizon during the day and decreases as it moves away from the observer.
#
# Overall, the combination of sunlight reflection off the Moon's surface and its own reflectivity makes the Moon a stunning celestial object that we can observe in the night sky.

# %%
# STREAM RESPONSE
response = ollama.generate(model="llama3.2:1b", prompt="Why Does moon glow ?", stream=True)

for i in response:
    print(i["response"], end="")
# Out:
# The moon glows because of a process called lunar illumination. Here's what happens:
#
# 1. **Sunlight reflection**: When the sun shines, it reflects sunlight towards the Earth. This reflected light is what we see as daylight.
# 2. **Moon's orbit**: The Moon orbits around the Earth, which means that it periodically passes in front of the sun and blocks some of its light.
# 3. **Shadow on the moon**: As the Moon moves through its orbit, different amounts of sunlight are blocked, creating shadows on its surface. These shadows are what give the Moon its appearance.
# 4. **Reflection of reflected light**: When sunlight reflects off the Moon's surface, it is then reflected back towards the Earth. This reflected light is what we see as a glowing, or illuminated, effect.
#
# There are several reasons why the moon glows:
#
# * **No atmosphere**: The Moon has no atmosphere to scatter or absorb the light, so the reflected light is not altered.
# * **Dark surface**: The Moon's surface is relatively dark compared to the Earth, which means that less of the sun's light is absorbed or scattered.
# * **Lunar regolith**: The Moon's surface is covered with a layer of regolith (soil) that reflects about 12% of incident sunlight.
#
# The amount and duration of lunar illumination can vary greatly depending on factors such as:
#
# * **Time of day**: During the full moon, the sun is overhead, and the reflected light from the Earth's atmosphere scatters in all directions, creating a bright glow.
# * **Moon phase**: The Moon's orbit around the Earth causes it to appear larger or smaller in the sky, which affects the amount of sunlight that reaches its surface.
# * **Atmospheric conditions**: Weather patterns and atmospheric conditions can influence the amount of scattered light that reaches the Moon.
#
# Overall, the combination of the sun's reflection off the Moon's surface and the lack of an atmosphere allows for a unique and captivating display – the moon glows!

# %%
# GIVING MULTIMODEL INPUT TO MODEL [PASSING IMAGE TO THE MODEL]

import base64
import ollama

image_path= "Linkedin.jpg"

with open(image_path,"rb") as f: # OPENING THE IMAGE IN READ BINARY 
    image_bytes= f.read()    # READING THE IMAGE 
image_64= base64.b64encode(image_bytes).decode("utf-8") # ENCODING THE IMAGE IN BASE 64 BITS.

response= ollama.generate(model="gemma3:4b", images=[image_64], prompt="Give caption for the image.")
print(response.response)
# Out:
# ---------------------------------------------------------------------------
# ResponseError                             Traceback (most recent call last)
# Cell In[13], line 12
#       9     image_bytes= f.read()    # READING THE IMAGE
#      10 image_64= base64.b64encode(image_bytes).decode("utf-8") # ENCODING THE IMAGE IN BASE 64 BITS.
# ---> 12 response= ollama.generate(model="gemma3:4b", images=[image_64], prompt="Give caption for the image.")
#      13 print(response.response)
#
# File c:\Users\write\AppData\Local\Programs\Python\Python311\Lib\site-packages\ollama\_client.py:262, in Client.generate(self, model, prompt, suffix, system, template, context, stream, think, logprobs, top_logprobs, raw, format, images, options, keep_alive)
#     233 def generate(
#     234   self,
#     235   model: str = '',
#    (...)    250   keep_alive: Optional[Union[float, str]] = None,
#     251 ) -> Union[GenerateResponse, Iterator[GenerateResponse]]:
#     252   """
#     253   Create a response using the requested model.
#     254
#    (...)    259   Returns `GenerateResponse` if `stream` is `False`, otherwise returns a `GenerateResponse` generator.
#     260   """
# --> 262   return self._request(
#     263     GenerateResponse,
#     264     'POST',
#     265     '/api/generate',
#     266     json=GenerateRequest(
#     267       model=model,
#     268       prompt=prompt,
#     269       suffix=suffix,
#     270       system=system,
#     271       template=template,
#     272       context=context,
#     273       stream=stream,
#     274       think=think,
#     275       logprobs=logprobs,
#     276       top_logprobs=top_logprobs,
#     277       raw=raw,
#     278       format=format,
#     279       images=list(_copy_images(images)) if images else None,
#     280       options=options,
#     281       keep_alive=keep_alive,
#     282     ).model_dump(exclude_none=True),
#     283     stream=stream,
#     284   )
#
# File c:\Users\write\AppData\Local\Programs\Python\Python311\Lib\site-packages\ollama\_client.py:189, in Client._request(self, cls, stream, *args, **kwargs)
#     185         yield cls(**part)
#     187   return inner()
# --> 189 return cls(**self._request_raw(*args, **kwargs).json())
#
# File c:\Users\write\AppData\Local\Programs\Python\Python311\Lib\site-packages\ollama\_client.py:133, in Client._request_raw(self, *args, **kwargs)
#     131   return r
#     132 except httpx.HTTPStatusError as e:
# --> 133   raise ResponseError(e.response.text, e.response.status_code) from None
#     134 except httpx.ConnectError:
#     135   raise ConnectionError(CONNECTION_ERROR_MESSAGE) from None
#
# ResponseError: model 'gemma3:4b' not found (status code: 404)

# %%
# PASSING MULTIPLE IMAGES TO THE MODEL.

image_paths = ["Linkedin.jpg","Green AI.png"]

images_base64=[]
for i in image_paths:
    with open(i , "rb") as f:
        image_bytes= f.read()
        images_base64.append(base64.b64encode(image_bytes).decode("utf-8"))

response= ollama.generate(model="gemma3:4b", images=images_base64,
                          prompt="Generate an story based on these images, make sure you take context from each and every image.")
print(response.response)

# %%
# SYSTEM INSTRUCTIONS
response = ollama.generate(model="llama3.2:1b",prompt="why does moon glow ?", system="You are an funny assistant , you explain things in funny way")
print(response.response)

# %%
response
# Out:
# GenerateResponse(model='llama3.2:1b', created_at='2026-02-02T18:18:25.8784742Z', done=True, done_reason='stop', total_duration=18217924800, load_duration=10561242000, prompt_eval_count=30, prompt_eval_duration=26026900, eval_count=435, eval_duration=6647181200, response="The Moon glows because of a process called photolysis, which occurs when sunlight interacts with the Moon's surface. Here's a simplified explanation:\n\n1. **Sunlight**: The Moon reflects about 12% of the Sun's light, and absorbs the remaining 88%. This is because the Moon has no atmosphere to scatter or absorb the shorter wavelengths of light (like blue and violet).\n2. **Reflective layer**: The Moon has a thin reflective layer on its surface, known as the lunar regolith. This layer is composed of finely granular particles of rock, glass, and metal that are ejected by meteorite impacts.\n3. **Excitation**: When sunlight hits the lunar regolith, it excites the tiny particles in the layer. These particles become energized and start to vibrate rapidly, like a guitar string plucked by an invisible hand.\n4. **Emission**: As the particles continue to vibrate, they release excess energy as light, which is emitted across a wide range of wavelengths (visible, ultraviolet, and even infrared). This process is called photoluminescence.\n5. **Glowing effect**: The resulting glow is what we see on Earth as the Moon appears to glow in the dark.\n\nThe color of the Moon's glow can vary depending on the wavelength of light that is emitted:\n\n* **Red**: Longer wavelengths (around 650-700 nanometers) are emitted, which is why the Moon often takes on a reddish hue during lunar eclipses.\n* **Blue**: Shorter wavelengths (around 400-500 nanometers) are emitted, which gives the Moon its characteristic bright blue color.\n* **Infrared**: The longest wavelengths (around 1-2 micrometers) are also emitted, but this is less visible to our eyes.\n\nIt's worth noting that the Moon's glow can be affected by various factors, such as:\n\n* **Atmospheric conditions**: A thin atmosphere on Mars allows for more efficient emission of light across a wider range of wavelengths.\n* **Dust and particle size**: Larger particles or dust can scatter shorter wavelengths of light, reducing their apparent brightness.", thinking=None, context=[128006, 9125, 128007, 271, 38766, 1303, 33025, 2696, 25, 6790, 220, 2366, 18, 271, 128009, 128006, 882, 128007, 271, 35734, 1587, 18266, 37066, 949, 128009, 128006, 78191, 128007, 271, 791, 17781, 2840, 4336, 1606, 315, 264, 1920, 2663, 4604, 337, 4548, 11, 902, 13980, 994, 40120, 84261, 449, 279, 17781, 596, 7479, 13, 5810, 596, 264, 44899, 16540, 1473, 16, 13, 3146, 31192, 4238, 96618, 578, 17781, 27053, 922, 220, 717, 4, 315, 279, 8219, 596, 3177, 11, 323, 91111, 279, 9861, 220, 2421, 14697, 1115, 374, 1606, 279, 17781, 706, 912, 16975, 311, 45577, 477, 35406, 279, 24210, 93959, 315, 3177, 320, 4908, 6437, 323, 80836, 4390, 17, 13, 3146, 73889, 535, 6324, 96618, 578, 17781, 706, 264, 15792, 52828, 6324, 389, 1202, 7479, 11, 3967, 439, 279, 57811, 1239, 48218, 13, 1115, 6324, 374, 24306, 315, 61802, 16109, 1299, 19252, 315, 7091, 11, 9168, 11, 323, 9501, 430, 527, 95503, 555, 42142, 635, 25949, 627, 18, 13, 3146, 42821, 7709, 96618, 3277, 40120, 13280, 279, 57811, 1239, 48218, 11, 433, 3521, 3695, 279, 13987, 19252, 304, 279, 6324, 13, 4314, 19252, 3719, 4602, 1534, 323, 1212, 311, 348, 44192, 19019, 11, 1093, 264, 17418, 925, 628, 40458, 555, 459, 30547, 1450, 627, 19, 13, 3146, 36, 2796, 96618, 1666, 279, 19252, 3136, 311, 348, 44192, 11, 814, 4984, 13937, 4907, 439, 3177, 11, 902, 374, 48042, 4028, 264, 7029, 2134, 315, 93959, 320, 12887, 11, 37232, 85311, 11, 323, 1524, 59141, 570, 1115, 1920, 374, 2663, 4604, 1152, 1572, 36634, 627, 20, 13, 3146, 38, 10516, 287, 2515, 96618, 578, 13239, 37066, 374, 1148, 584, 1518, 389, 9420, 439, 279, 17781, 8111, 311, 37066, 304, 279, 6453, 382, 791, 1933, 315, 279, 17781, 596, 37066, 649, 13592, 11911, 389, 279, 46406, 31 ...

# %%
# OPTIONS PARAMETER
response = ollama.generate(model="llama3.2:1b",prompt="why is the ocean blue",
                           options={
                               "temperature":0.3,
                               "top_p":0.5,
                               "top_k":45
                           })


print(response.response)

# %%
#OLLAMA LIST
local_models= ollama.list()
print(local_models)

print("**************************")

for i in local_models["models"]:
    print(i["model"])
    print(i["size"])

# %%
#OLLAMA PULL
model_name="deepseek-r1"
progess = ollama.pull(model_name, stream=True)

for i in progess:
    print(i)

# %%
#OLLAMA SHOW
models_details = ollama.show("qwen3:8b")
#print(models_details)
print(models_details.dict())

# %%
model_dict= models_details.dict()
print(model_dict["capabilities"])
print(model_dict["parameters"])
