# %% [markdown]
# # LeNet

# %% [markdown]
# <big>LeNet-5 is one of the first Convolutional Neural Networks (CNNs), developed by Yann LeCun in 1998. It was designed for handwritten digit recognition (MNIST dataset).

# %% [markdown]
# ![image.png](attachment:dfdda162-4d52-4981-a0ff-4024c92a979a.png)

# %%
import tensorflow as tf
from tensorflow import keras
from keras import Sequential
from keras.layers import Dense, Conv2D, Flatten, AveragePooling2D
from keras.datasets import mnist

# %%
(X_train, y_train), (X_test, y_test) = mnist.load_data()

# %% [markdown]
# # LeNet Architecture

# %%
model = Sequential()

model.add(Conv2D(6, kernel_size=(5,5), padding='valid', activation='tanh', input_shape=(32,32,1)))
model.add(AveragePooling2D(pool_size=(2,2), strides=2, padding='valid'))

model.add(Conv2D(16, kernel_size=(5,5), padding='valid', activation='tanh'))
model.add(AveragePooling2D(pool_size=(2,2), strides=2, padding='valid'))

model.add(Flatten())

model.add(Dense(120, activation='tanh'))
model.add(Dense(84, activation='tanh'))
model.add(Dense(10, activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d_4 (Conv2D)           (None, 28, 28, 6)         156
#
#  average_pooling2d_4 (Averag  (None, 14, 14, 6)        0
#  ePooling2D)
#
#  conv2d_5 (Conv2D)           (None, 10, 10, 16)        2416
#
#  average_pooling2d_5 (Averag  (None, 5, 5, 16)         0
#  ePooling2D)
#
#  flatten_2 (Flatten)         (None, 400)               0
#
#  dense_6 (Dense)             (None, 120)               48120
#
#  dense_7 (Dense)             (None, 84)                10164
#
#  dense_8 (Dense)             (None, 10)                850
#
# ...
# Total params: 61,706
# Trainable params: 61,706
# Non-trainable params: 0
# _________________________________________________________________
