# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/credit-card-customer-churn-prediction/Churn_Modelling.csv

# %%
df = pd.read_csv('/kaggle/input/credit-card-customer-churn-prediction/Churn_Modelling.csv')

# %%
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# 4         79084.10       0

# %%
df.shape
# Out:
# (10000, 14)

# %%
df.info
# Out:
# <bound method DataFrame.info of       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0          2       0.00              1          1               1
# 1          1   83807.86              1          0               1
# 2          8  159660.80              3          1               0
# 3          1       0.00              2          0               0
# 4          2  125510.82              1          1               1
# ...      ...        ...            ...        ...             ...
# 9995       5       0.00              2          1               0
# 9996      10   57369.61              1          1               1
# 9997       7       0.00              1          0               1
# 9998       3   75075.31              2          1               0
# 9999       4  130142.79              1          1               0
#
#       EstimatedSalary  Exited
# 0           101348.88       1
# 1           112542.58       0
# 2           113931.57       1
# 3            93826.63       0
# 4            79084.10       0
# ...               ...     ...
# 9995         96270.64       0
# 9996        101699.77       0
# 9997         42085.58       1
# 9998         92888.52       1
# 9999         38190.78       0
#
# [10000 rows x 14 columns]>

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df['Exited'].value_counts()
# Out:
# Exited
# 0    7963
# 1    2037
# Name: count, dtype: int64

# %%
df['Geography'].value_counts()
# Out:
# Geography
# France     5014
# Germany    2509
# Spain      2477
# Name: count, dtype: int64

# %%
df['Gender'].value_counts()
# Out:
# Gender
# Male      5457
# Female    4543
# Name: count, dtype: int64

# %%
df.drop(columns=['RowNumber', 'CustomerId', 'Surname'], inplace=True)

# %%
df.shape
# Out:
# (10000, 11)

# %%
df.head()
# Out:
#    CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0          619    France  Female   42       2       0.00              1
# 1          608     Spain  Female   41       1   83807.86              1
# 2          502    France  Female   42       8  159660.80              3
# 3          699    France  Female   39       1       0.00              2
# 4          850     Spain  Female   43       2  125510.82              1
#
#    HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0          1               1        101348.88       1
# 1          0               1        112542.58       0
# 2          1               0        113931.57       1
# 3          0               0         93826.63       0
# 4          1               1         79084.10       0

# %%
df = pd.get_dummies(df, columns=['Geography', 'Gender'], drop_first=True)

# %%
df.head()
# Out:
#    CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0          619   42       2       0.00              1          1
# 1          608   41       1   83807.86              1          0
# 2          502   42       8  159660.80              3          1
# 3          699   39       1       0.00              2          0
# 4          850   43       2  125510.82              1          1
#
#    IsActiveMember  EstimatedSalary  Exited  Geography_Germany  \
# 0               1        101348.88       1              False
# 1               1        112542.58       0              False
# 2               0        113931.57       1              False
# 3               0         93826.63       0              False
# 4               1         79084.10       0              False
#
#    Geography_Spain  Gender_Male
# 0            False        False
# 1             True        False
# 2            False        False
# 3            False        False
# 4             True        False

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(df.drop(columns=['Exited']), df['Exited'], test_size=0.1, random_state=42)

# %%
X_train.shape
# Out:
# (9000, 11)

# %%
X_test.shape
# Out:
# (1000, 11)

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.fit_transform(X_test)

# %%
X_train_scaled
# Out:
# array([[-0.47944328,  0.19687202, -0.00234647, ..., -0.5761528 ,
#         -0.57700814,  0.91105005],
#        [ 1.04580863,  1.33803657,  1.03625698, ..., -0.5761528 ,
#         -0.57700814, -1.09763453],
#        [-0.85297437, -0.08841912,  1.03625698, ..., -0.5761528 ,
#          1.73307782,  0.91105005],
#        ...,
#        [ 0.86941896, -0.08841912, -1.38715108, ..., -0.5761528 ,
#         -0.57700814, -1.09763453],
#        [ 0.16386025,  0.38706611,  1.03625698, ..., -0.5761528 ,
#         -0.57700814,  0.91105005],
#        [ 0.47513615,  1.14784248, -1.38715108, ...,  1.73565068,
#         -0.57700814,  0.91105005]])

# %%
X_train_scaled
# Out:
# array([[-0.47944328,  0.19687202, -0.00234647, ..., -0.5761528 ,
#         -0.57700814,  0.91105005],
#        [ 1.04580863,  1.33803657,  1.03625698, ..., -0.5761528 ,
#         -0.57700814, -1.09763453],
#        [-0.85297437, -0.08841912,  1.03625698, ..., -0.5761528 ,
#          1.73307782,  0.91105005],
#        ...,
#        [ 0.86941896, -0.08841912, -1.38715108, ..., -0.5761528 ,
#         -0.57700814, -1.09763453],
#        [ 0.16386025,  0.38706611,  1.03625698, ..., -0.5761528 ,
#         -0.57700814,  0.91105005],
#        [ 0.47513615,  1.14784248, -1.38715108, ...,  1.73565068,
#         -0.57700814,  0.91105005]])

# %%
import tensorflow
from tensorflow import keras
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense

# %%
model = Sequential()

# %%
# architecture of model
model.add(Dense(11, activation='relu', input_dim=11))
model.add(Dense(11, activation='relu', input_dim=11))
model.add(Dense(1, activation='sigmoid'))
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_3 (Dense)                      │ (None, 11)                  │             132 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 11)                  │             132 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_5 (Dense)                      │ (None, 1)                   │              12 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 276 (1.08 KB)
#  Trainable params: 276 (1.08 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(loss='binary_crossentropy', optimizer='Adam', metrics=['accuracy'])

# %%
history = model.fit(X_train_scaled, y_train, epochs=50, validation_split=0.2)
# Out:
# Epoch 1/50
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7804 - loss: 0.5785 - val_accuracy: 0.7950 - val_loss: 0.4919
# Epoch 2/50
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7951 - loss: 0.4801 - val_accuracy: 0.8111 - val_loss: 0.4380
# Epoch 3/50
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8147 - loss: 0.4361 - val_accuracy: 0.8194 - val_loss: 0.4235
# Epoch 4/50
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8230 - loss: 0.4175 - val_accuracy: 0.8222 - val_loss: 0.4160
# Epoch 5/50
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8197 - loss: 0.4200 - val_accuracy: 0.8328 - val_loss: 0.4093
# Epoch 6/50
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8305 - loss: 0.4003 - val_accuracy: 0.8372 - val_loss: 0.4038
# Epoch 7/50
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8328 - loss: 0.3984 - val_accuracy: 0.8383 - val_loss: 0.3965
# Epoch 8/50
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8396 - loss: 0.3912 - val_accuracy: 0.8433 - val_loss: 0.3881
# Epoch 9/50
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8377 - loss: 0.3838 - val_accuracy: 0.8433 - val_loss: 0.3771
# Epoch 10/50
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8496 - loss: 0.3642 - val_accuracy: 0.8578 - val_loss: 0.3685
# Epoch 11/50
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8507 - loss: 0.3691 - val_accuracy: 0.8539 - val_loss: 0.3605
# Epoch 12/50
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8547 - loss: 0.3513 - val_accuracy: 0.8550 - val_loss: 0.3558
# Epoch 13/50
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8517 - loss: 0.3539 - val_accuracy: 0.8567 - val_loss: 0.3537
# Epoch 14/50
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8630 - loss: 0.3399 - val_accuracy: 0.8583 - val_loss: 0.3507
# Epoch 15/50
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8581 - loss: 0.3383 - val_accuracy: 0.8594 - val_loss: 0.3502
# Epoch 16/50
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8643 - loss: 0.3295 - val_accuracy: 0.8572 - val_loss: 0.3484
# Epoch 17/50
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8643 - loss: 0.3271 - val_accuracy: 0.8583 - val_loss: 0.3488
# Epoch 18/50
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8563 - loss: 0.3471 - val_accuracy: 0.8644 - val_loss: 0.3488
# Epoch 19/50
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8628 - loss: 0.3330 - val_accuracy: 0.8644 - val_loss: 0.3463
# Epoch 20/50
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8640 - loss: 0.3315 - val_accuracy: 0.8628 - val_loss: 0.3473
# Epoch 21/50
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8695 - loss: 0.3296 - val_accuracy: 0.8617 - val_loss: 0.3465
# Epoch 22/50
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8671 - loss: 0.3296 - val_accuracy: 0.8639 - val_loss: 0.3451
# Epoch 23/50
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8644 - loss: 0.3320 - val_accuracy: 0.8594 - val_loss: 0.3489
# Epoch 24/50
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8695 - loss: 0.3267 - val_accuracy: 0.8611 - val_loss: 0.3453
# Epoch 25/50
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8621 - loss: 0.3398 - val_accuracy: 0.8611 - val_loss: 0.3450
# Epoch 26/50
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8672 - loss: 0.3322 - val_accuracy: 0.8611 - val_loss: 0.3442
# Epoch 27/50
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8644 - loss: 0.3300 - val_accuracy: 0.8578 - val_loss: 0.3458
# Epoch 28/50
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8646 - loss: 0.3349 - val_accuracy: 0.8600 - val_loss: 0.3449
# Epoch 29/50
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8633 - loss: 0.3381 - val_accuracy: 0.8606 - val_loss: 0.3446
# Epoch 30/50
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8649 - loss: 0.3328 - val_accuracy: 0.8556 - val_loss: 0.3454
# Epoch 31/50
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8648 - loss: 0.3260 - val_accuracy: 0.8572 - val_loss: 0.3448
# Epoch 32/50
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8706 - loss: 0.3323 - val_accuracy: 0.8561 - val_loss: 0.3458
# Epoch 33/50
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8716 - loss: 0.3274 - val_accuracy: 0.8556 - val_loss: 0.3448
# Epoch 34/50
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8630 - loss: 0.3378 - val_accuracy: 0.8556 - val_loss: 0.3459
# Epoch 35/50
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8695 - loss: 0.3229 - val_accuracy: 0.8561 - val_loss: 0.3454
# Epoch 36/50
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8678 - loss: 0.3250 - val_accuracy: 0.8578 - val_loss: 0.3445
# Epoch 37/50
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8681 - loss: 0.3322 - val_accuracy: 0.8561 - val_loss: 0.3449
# Epoch 38/50
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8722 - loss: 0.3205 - val_accuracy: 0.8539 - val_loss: 0.3443
# Epoch 39/50
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8739 - loss: 0.3216 - val_accuracy: 0.8544 - val_loss: 0.3439
# Epoch 40/50
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8595 - loss: 0.3340 - val_accuracy: 0.8578 - val_loss: 0.3464
# Epoch 41/50
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8677 - loss: 0.3252 - val_accuracy: 0.8561 - val_loss: 0.3450
# Epoch 42/50
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8716 - loss: 0.3264 - val_accuracy: 0.8533 - val_loss: 0.3446
# Epoch 43/50
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8632 - loss: 0.3313 - val_accuracy: 0.8539 - val_loss: 0.3460
# Epoch 44/50
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8674 - loss: 0.3270 - val_accuracy: 0.8550 - val_loss: 0.3467
# Epoch 45/50
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8741 - loss: 0.3114 - val_accuracy: 0.8556 - val_loss: 0.3463
# Epoch 46/50
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8702 - loss: 0.3269 - val_accuracy: 0.8544 - val_loss: 0.3457
# Epoch 47/50
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8650 - loss: 0.3189 - val_accuracy: 0.8572 - val_loss: 0.3454
# Epoch 48/50
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8725 - loss: 0.3162 - val_accuracy: 0.8556 - val_loss: 0.3451
# Epoch 49/50
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8649 - loss: 0.3309 - val_accuracy: 0.8517 - val_loss: 0.3458
# Epoch 50/50
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8671 - loss: 0.3263 - val_accuracy: 0.8511 - val_loss: 0.3465

# %%
model.layers
# Out:
# [<Dense name=dense_3, built=True>,
#  <Dense name=dense_4, built=True>,
#  <Dense name=dense_5, built=True>]

# %%
model.layers[0].get_weights()
# Out:
# [array([[ 0.06132789,  0.05963001,  0.35891098,  0.06227623,  0.18640551,
#          -0.3413835 ,  0.13996558,  0.00347332,  0.03076234,  0.08735689,
#           0.06654061],
#         [-0.6098482 ,  0.6090909 ,  0.34147763,  1.327053  , -0.3709023 ,
#           0.183175  ,  0.08863585, -0.5957645 ,  0.3122229 ,  0.2833641 ,
#           0.1701321 ],
#         [-0.18446219,  0.28709212,  0.17461741, -0.08270258,  0.18857442,
#           0.08678518,  0.08906274,  0.09924805,  0.1912706 , -0.0590896 ,
#           0.1366877 ],
#         [-0.29737833,  0.39716953,  0.11877499,  0.02954652,  0.3188086 ,
#          -0.4701231 , -0.79368585, -0.248585  , -0.12783481, -0.01912762,
#           0.40883514],
#         [-0.04355522, -0.05020786,  0.07924403,  0.33841085, -0.15467842,
#           0.45543092, -0.14502434, -0.39000502, -1.0471021 , -0.89928144,
#           1.171486  ],
#         [-0.06551564,  0.15048413,  0.03715902,  0.09606536,  0.169352  ,
#          -0.30749223, -0.02591149, -0.06052845,  0.10316584, -0.05529509,
#          -0.08763649],
#         [ 0.76166004,  0.73346394, -0.48828173,  0.2625613 , -0.01849778,
#           0.7780017 ,  0.4186976 , -0.5853042 ,  0.02296345, -0.26239613,
#          -0.37848812],
#         [-0.08035637, -0.1336153 ,  0.20468573, -0.08012076, -0.13829538,
#          -0.13120437,  0.1294513 , -0.4977124 , -0.2826573 ,  0.00203679,
#          -0.07690414],
#         [-0.17022298, -0.44146618, -0.47959447,  0.06495555,  0.3568572 ,
#           0.21835966, -0.12538584, -0.19907519,  0.21595947,  0.09663519,
#          -0.10917543],
#         [-0.01816693,  0.32378864,  0.30507654,  0.15810856, -0.59211224,
#           0.30142987, -0.0132557 ,  0.19958971,  0.14769384,  0.01981994,
#           0.14336921],
#         [ 0.33602262,  0.09096711,  0.50397   ,  0.14677419, -0.15620562,
#           0.6084719 , -0.29822078, -0.06480352, -0.2310991 ,  0.22158793,
#          -0.07784   ]], dtype=float32),
#  array([ 0.6460477 , -0.20191506,  0.38487208, -0.71508557,  0.7187525 ,
#         -0.1512458 ,  0.22264448,  0.46339983,  0.15528555,  0.11046331,
#         -0.05764269], dtype=float32)]

# %%
y_log = model.predict(X_test_scaled)
# Out:
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step

# %%
y_pred = np.where(y_log > 0.5, 1, 0)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test, y_pred)
# Out:
# 0.855

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
