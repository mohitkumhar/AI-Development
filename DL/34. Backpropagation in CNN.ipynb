# %% [markdown]
# ## Proper Flow of How a Convolutional Neural Network (CNN) works

# %% [markdown]
# **Input → Convolution → ReLU Activation → Pooling → Flatten → Fully Connected Layer → Output (Softmax/Sigmoid/Linear)**
