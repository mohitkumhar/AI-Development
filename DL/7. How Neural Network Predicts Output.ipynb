# %% [markdown]
# ![image.png](attachment:098092a3-e96a-473a-9cbb-ee6dfdf5155b.png)

# %% [markdown]
# #### Layer 1 (Input Layer)
# Inputs: X = [xi1 , xi2, xi3, xi4]T (a 4 x 1 columns vector)<br>
# These inputs are connected to the neurons in the next layer through weights.

# %% [markdown]
# #### Layer 2 (Hidden Layer)
#
# The weight matrix 𝑊(1) (connecting input to the hidden layer) has a shape of 4×3:
# ![image.png](attachment:34403414-7e1c-4311-ac59-34fda5b25293.png) <br>
# (Each column represents weights for one neuron in the hidden layer.)
#
# - Compute the weighted sum:
# - ![image.png](attachment:6cfee4b4-7f1f-4e77-866c-c724da976a40.png)
# - Where B(1) is the bias vector
# - ![image.png](attachment:301d520c-5714-4ede-8b89-60c8d99afd0a.png)
# - This results in a 3×1 output vector.
# - Apply an activation function 𝜎(𝑍) (e.g., ReLU or Sigmoid) to get activations 𝐴(1)

# %% [markdown]
# #### Layer 3 (Output Layer)
# - The hidden layer's activations 𝐴(1) now become the input for the output layer.
# - The weight matrix for this layer is 3x1
# ![image.png](attachment:ad97c1d6-60ba-4c85-9104-5ce67105eb1b.png)

# %% [markdown]
# ![image.png](attachment:a0297952-fee5-4b48-b3ee-80ee3cb7ccfc.png)
