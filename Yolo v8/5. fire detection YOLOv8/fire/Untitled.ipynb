# %%
from ultralytics import YOLO

# %%
model = YOLO()

# %%
model.train(data=r'F:\ai\AI-Development\Yolo v8\5. fire detection YOLOv8\fire\data.yaml', epochs=100, augment=False)
# Out:
# Ultralytics 8.3.91  Python-3.10.6 torch-2.6.0+cu118 CUDA:0 (NVIDIA GeForce RTX 2050, 4096MiB)
# ...

# %%
model = r'F:\ai\AI-Development\Yolo v8\5. fire detection YOLOv8\fire\runs\detect\train9\weights\best.pt'

# %%
from ultralytics import YOLO
import cv2
from matplotlib import pyplot as plt
from PIL import Image

# %%
model = YOLO(model)

# %%
file_path = r'F:\ai\AI-Development\Yolo v8\5. fire detection YOLOv8\fire\fire.jpg'

results = model.predict(source=file_path,conf=.5, save=False)

for r in results:
    img = r.plot()  # Get annotated image as numpy array
    img = Image.fromarray(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
    img.show()
# Out:
# image 1/1 F:\ai\AI-Development\Yolo v8\5. fire detection YOLOv8\fire\fire.jpg: 448x640 1 fire, 158.2ms
# Speed: 12.1ms preprocess, 158.2ms inference, 31.5ms postprocess per image at shape (1, 3, 448, 640)

# %% [markdown]
# ## using web came

# %%
import cv2
from PIL import Image
import numpy as np

# Initialize the webcam
cap = cv2.VideoCapture(0)  # 0 for the default camera

while True:
    ret, frame = cap.read()
    if not ret:
        break

    # Run YOLO prediction on the frame
    results = model.predict(source=frame, conf=0.3, save=False)

    for r in results:
        # Get annotated frame
        annotated_frame = r.plot()

        # Display the annotated frame
        cv2.imshow("YOLOv8 Detection", annotated_frame)

    # Press 'q' to exit the loop
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release the webcam and close the window
cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 480x640 (no detections), 26.6ms
# Speed: 5.1ms preprocess, 26.6ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 22.4ms
# Speed: 2.8ms preprocess, 22.4ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 21.6ms
# Speed: 3.1ms preprocess, 21.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 26.5ms
# Speed: 2.5ms preprocess, 26.5ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 26.1ms
# Speed: 2.5ms preprocess, 26.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 31.2ms
# Speed: 2.6ms preprocess, 31.2ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 16.5ms
# Speed: 2.4ms preprocess, 16.5ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# ...
