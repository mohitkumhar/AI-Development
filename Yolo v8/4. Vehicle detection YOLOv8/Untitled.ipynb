# %%
from ultralytics import YOLO

# %%
model = YOLO('yolov8n.pt') # load a pretrained model

# %% [markdown]
# #### hyper parameter using following parameters
# <pre>
# model.train(
#     data='data.yaml',
#     epochs=150,
#     batch=16,
#     imgsz=640,
#     lr0=0.001,
#     lrf=0.01,
#     momentum=0.9,
#     weight_decay=0.0005,
#     optimizer='AdamW',
#     patience=25,
#     warmup_epochs=3,
#     scale=0.5,
#     hsv_h=0.02,
#     hsv_s=0.7,
#     hsv_v=0.4,
#     fliplr=0.5,
#     flipud=0.3
# )
# </pre>

# %%
model.train(data='data.yaml', epochs=100)  # train the model
# Out:
# Ultralytics 8.3.91  Python-3.10.6 torch-2.6.0+cu118 CUDA:0 (NVIDIA GeForce RTX 2050, 4096MiB)
# ...

# %%
from ultralytics import YOLO

# %%
model = YOLO(r'F:\ai\AI-Development\Yolo v8\4. Vehicle detection YOLOv8\runs\detect\train3\weights\best.pt')

# %%
import cv2
from matplotlib import pyplot as plt
from PIL import Image

# %%
file_path=r'F:\ai\AI-Development\Yolo v8\4. Vehicle detection YOLOv8\highway.jpg'

results = model.predict(source=file_path,conf=.5, save=False)

for r in results:
    img = r.plot()  # Get annotated image as numpy array
    img = Image.fromarray(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
    img.show()
# Out:
# image 1/1 F:\ai\AI-Development\Yolo v8\4. Vehicle detection YOLOv8\highway.jpg: 480x640 15 Cars, 7 Trucks, 85.6ms
# Speed: 11.3ms preprocess, 85.6ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)

# %%
model.names
# Out:
# {0: 'Car', 1: 'Motorcycle', 2: 'Truck', 3: 'Bus', 4: 'Bicycle'}
