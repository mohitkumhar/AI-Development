# %%
from ultralytics import YOLO

# %%
# load a model
model = YOLO()  # build new model from scratch

results = model.train(data=r'F:\ai\AI-Development\Yolo v8\2. Image Segmentation On Custom Dataset using YOLOv8\pets dataset\data.yaml', epochs=200, workers=1, batch=8, imgsz=640) # train the mode
# Out:
# Ultralytics 8.3.91  Python-3.10.6 torch-2.6.0+cu118 CUDA:0 (NVIDIA GeForce RTX 2050, 4096MiB)
# ...

# %%
from matplotlib import pyplot as plt
import cv2
# predicting model

from ultralytics import YOLO

# load the model
model = YOLO(r'F:\ai\AI-Development\Yolo v8\2. Image Segmentation On Custom Dataset using YOLOv8\runs\detect\train4\weights\best.pt')

results = model.predict(source=r'F:\ai\AI-Development\Yolo v8\2. Image Segmentation On Custom Dataset using YOLOv8\pets dataset\test\images', task='classification', save=False) # use source 0 for webcam, and location of image or image folder

for result in results:
    img = result.plot()
    plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB)) # Convert BGR to RGB for display
    plt.axis('off')
    plt.show()
# Out:
# image 1/10 F:\ai\AI-Development\Yolo v8\2. Image Segmentation On Custom Dataset using YOLOv8\pets dataset\test\images\Abyssinian_127_jpg.rf.4425d22917ead085ad038931b4806c8f.jpg: 640x448 1 cat, 81.7ms
# image 2/10 F:\ai\AI-Development\Yolo v8\2. Image Segmentation On Custom Dataset using YOLOv8\pets dataset\test\images\Abyssinian_131_jpg.rf.e8acfb60e4d01529586b9d81930b35a2.jpg: 640x640 1 cat, 117.4ms
# image 3/10 F:\ai\AI-Development\Yolo v8\2. Image Segmentation On Custom Dataset using YOLOv8\pets dataset\test\images\Abyssinian_149_jpg.rf.84b8351968b42b38478e0b6c35d58d07.jpg: 480x640 1 cat, 44.3ms
# image 4/10 F:\ai\AI-Development\Yolo v8\2. Image Segmentation On Custom Dataset using YOLOv8\pets dataset\test\images\Abyssinian_155_jpg.rf.b0d3e78a69efe3c9aa7bd4416a51e105.jpg: 416x640 1 cat, 54.2ms
# ...
